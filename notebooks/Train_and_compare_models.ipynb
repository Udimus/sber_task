# %% [markdown]
# # Задача
#
# Мы хотим обучить lightgbm и catboost как с использованием их встроенных методов для обработки категориальных признаков, так и предварительно обработав нашими методами. И сравнить полученное качество.
#
# Для оценки качества будем использовать кросс-валидацию.
#
# Для упрощения не будем отвлекаться на подбор гиперпараметров, для более корректной оценки не будем делать early_stopping.
#
#
# После этого мы сохраним предсказания для теста для этих четырёх вариантов. И также сохраним лучшую модель.

# %% [markdown]
# # Импорты

# %%
import os
import logging
from pprint import pprint

import pandas as pd
from sklearn.pipeline import Pipeline
from sklearn.model_selection import cross_val_score
from sklearn.metrics import make_scorer
from tqdm import tqdm_notebook

from module.prepare_data import (
    BinFeaturesTransformer,
    CatFeaturesTransformer,
    DropTransformer,
)
from module.model import (
    OurLossCBObjective,
    OurLossCBMetric,
    our_loss_function,
    our_loss_lgbm_objective,
    CatboostWrapper,
    LightgbmWrapper,
    save_pipeline,
    load_pipeline,
)

# %%
# MODE = 'DEBUG'
MODE = 'FULL'

logging.basicConfig(
    level=('DEBUG' if MODE == 'DEBUG' else 'INFO'),
    format='%(asctime)s %(levelname)s:%(module)s %(message)s'
)

# %%
logger = logging.getLogger()

# %% [markdown]
# # Загрузка данных

# %%
DATA_PATH = '../data'
TRAIN_FILE = 'TRAIN_DATA.csv'
TEST_FILE = 'TEST_DATA.csv'

# %%
train_data = pd.read_csv(os.path.join(DATA_PATH, TRAIN_FILE))

# %%
train_data.head()
# Out:
#    row_id    target feat_0 feat_1 feat_2 feat_3 feat_4   feat_5 feat_6 feat_7  \
# 0       2  10024.24      A      D      A      A      A  0.69840      A      A
# 1       3   5887.65      A      A      A      A      A  0.24564      A      A
# 2       4  21015.57      A      D      A      A      A  0.28768      A      A
# 3       6   6251.75      A      D      A      A      A  0.34987      A      A
# 4       7   1899.61      A      D      A      A      B  0.49462      A      A
#
#    ... feat_120  feat_121 feat_122 feat_123  feat_124  feat_125 feat_126  \
# 0  ...        A         L        A       BI         A  0.464228        T
# 1  ...        A         K        A       BI         A  0.330514        P
# 2  ...        A         G        A       BI         A  0.400280        T
# 3  ...        A         A        A       BI         A  0.438385        T
# 4  ...        A         I        A       BI         A  0.485918        T
#
#   feat_127 feat_128 feat_129
# 0        A        A        B
# 1        A        A        A
# 2        A        A        A
# 3        A        A        A
# 4        A        A        B
#
# [5 rows x 132 columns]

# %%
train_data = train_data[:10000] if MODE == 'DEBUG' else train_data

# %%
len(train_data)
# Out:
# 143121

# %% [markdown]
# # Подготовка pipeline'ов.

# %% [markdown]
# Рассмотрим следующие варианты:
# * Преобразовывать ли бинарные признаки в числа?
# * Предобрабатывать ли категориальные признаки своими силами?
# * Если нет -- отдавать их как категориальные или вообще выбросить?
# * Какую из моделей применять?

# %%
bin_as_num_features = BinFeaturesTransformer(bin_as_numeric=True).get_features()
bin_as_cat_features = BinFeaturesTransformer(bin_as_numeric=False).get_features()

# %%
pipeline_name_pattern = 'bin:{},prepare:{},model:{},metric:{}'
bin_features_params = {
    'num': {
        'bin_as_numeric': True,
        'cat_features': bin_as_num_features['cat_features'],
    },
    'cat': {
        'bin_as_numeric': False,
        'cat_features': bin_as_cat_features['cat_features'],
    },
}
prepare_params = {
    'exp': {
        'expanding': True,
        'alpha': 0,
    },
    'alpha_0': {
        'alpha': 0,
        'expanding': False,
    },
    'alpha_1': {
        'alpha': 10,
        'expanding': False,
    },
    'alpha_10': {
        'alpha': 100,
        'expanding': False,
    },
    'alpha_100': {
        'alpha': 1000,
        'expanding': False,
    },
    'no': {},
    'drop': {}
}
models = ['cb', 'lgbm']
metrics = ['our', 'default']

# %%
pipelines = dict()
for bin_type in bin_features_params:
    for prepare_type in prepare_params:
        for model in models:
            for metric in metrics:
                name = pipeline_name_pattern.format(bin_type,
                                                    prepare_type,
                                                    model,
                                                    metric)
                bin_params = bin_features_params[bin_type].copy()
                prep_params = prepare_params[prepare_type]
                pipeline_list = []
                pipeline_list.append(('bin_transform',
                                      BinFeaturesTransformer(bin_as_numeric=bin_params.pop('bin_as_numeric'))))
                model_params = {'n_estimators': 100}
                if MODE == 'DEBUG':
                    model_params['verbose'] = 1
                if prepare_type == 'drop':
                    pipeline_list.append(('drop_transform',
                                          DropTransformer(drop_columns=bin_params['cat_features'])))
                elif prepare_type == 'no': 
                    model_params.update(bin_params)
                else:
                    pipeline_list.append(('cat_transform',
                                          CatFeaturesTransformer(**{**bin_params, **prep_params})))
                if model == 'cb':
                    if metric == 'our':
                        model_params.update({
                            'loss_function': OurLossCBObjective(),
                            'eval_metric': OurLossCBMetric(),
                        })
                    pipeline_list.append(('regressor',
                                          CatboostWrapper(**model_params)))
                else:
                    if metric == 'our':
                        model_params.update({
                            'objective': our_loss_lgbm_objective,
                        })
                    pipeline_list.append(('regressor',
                                          LightgbmWrapper(**model_params)))
                pipelines[name] = Pipeline(pipeline_list)

# %%
len(pipelines)
# Out:
# 56

# %%
pprint(list(pipelines.keys()))
# Out:
# ['bin:num,prepare:exp,model:cb,metric:our',
#  'bin:num,prepare:exp,model:cb,metric:default',
#  'bin:num,prepare:exp,model:lgbm,metric:our',
#  'bin:num,prepare:exp,model:lgbm,metric:default',
#  'bin:num,prepare:alpha_0,model:cb,metric:our',
#  'bin:num,prepare:alpha_0,model:cb,metric:default',
#  'bin:num,prepare:alpha_0,model:lgbm,metric:our',
#  'bin:num,prepare:alpha_0,model:lgbm,metric:default',
#  'bin:num,prepare:alpha_1,model:cb,metric:our',
#  'bin:num,prepare:alpha_1,model:cb,metric:default',
#  'bin:num,prepare:alpha_1,model:lgbm,metric:our',
#  'bin:num,prepare:alpha_1,model:lgbm,metric:default',
#  'bin:num,prepare:alpha_10,model:cb,metric:our',
#  'bin:num,prepare:alpha_10,model:cb,metric:default',
#  'bin:num,prepare:alpha_10,model:lgbm,metric:our',
#  'bin:num,prepare:alpha_10,model:lgbm,metric:default',
#  'bin:num,prepare:alpha_100,model:cb,metric:our',
#  'bin:num,prepare:alpha_100,model:cb,metric:default',
#  'bin:num,prepare:alpha_100,model:lgbm,metric:our',
#  'bin:num,prepare:alpha_100,model:lgbm,metric:default',
#  'bin:num,prepare:no,model:cb,metric:our',
#  'bin:num,prepare:no,model:cb,metric:default',
#  'bin:num,prepare:no,model:lgbm,metric:our',
#  'bin:num,prepare:no,model:lgbm,metric:default',
#  'bin:num,prepare:drop,model:cb,metric:our',
#  'bin:num,prepare:drop,model:cb,metric:default',
#  'bin:num,prepare:drop,model:lgbm,metric:our',
#  'bin:num,prepare:drop,model:lgbm,metric:default',
#  'bin:cat,prepare:exp,model:cb,metric:our',
#  'bin:cat,prepare:exp,model:cb,metric:default',
#  'bin:cat,prepare:exp,model:lgbm,metric:our',
#  'bin:cat,prepare:exp,model:lgbm,metric:default',
#  'bin:cat,prepare:alpha_0,model:cb,metric:our',
#  'bin:cat,prepare:alpha_0,model:cb,metric:default',
#  'bin:cat,prepare:alpha_0,model:lgbm,metric:our',
#  'bin:cat,prepare:alpha_0,model:lgbm,metric:default',
#  'bin:cat,prepare:alpha_1,model:cb,metric:our',
#  'bin:cat,prepare:alpha_1,model:cb,metric:default',
#  'bin:cat,prepare:alpha_1,model:lgbm,metric:our',
#  'bin:cat,prepare:alpha_1,model:lgbm,metric:default',
#  'bin:cat,prepare:alpha_10,model:cb,metric:our',
#  'bin:cat,prepare:alpha_10,model:cb,metric:default',
#  'bin:cat,prepare:alpha_10,model:lgbm,metric:our',
#  'bin:cat,prepare:alpha_10,model:lgbm,metric:default',
#  'bin:cat,prepare:alpha_100,model:cb,metric:our',
#  'bin:cat,prepare:alpha_100,model:cb,metric:default',
#  'bin:cat,prepare:alpha_100,model:lgbm,metric:our',
#  'bin:cat,prepare:alpha_100,model:lgbm,metric:default',
#  'bin:cat,prepare:no,model:cb,metric:our',
#  'bin:cat,prepare:no,model:cb,metric:default',
#  'bin:cat,prepare:no,model:lgbm,metric:our',
#  'bin:cat,prepare:no,model:lgbm,metric:default',
#  'bin:cat,prepare:drop,model:cb,metric:our',
#  'bin:cat,prepare:drop,model:cb,metric:default',
#  'bin:cat,prepare:drop,model:lgbm,metric:our',
#  'bin:cat,prepare:drop,model:lgbm,metric:default']

# %% [markdown]
# # Кросс-валидация
#
# Будем проверять по семи фолдам.

# %%
scorer = make_scorer(our_loss_function, greater_is_better=False)

# %%
pipelines_scores = dict()
n_folds = 7

# %%
for name in tqdm_notebook(pipelines):
    pipelines_scores[name] = cross_val_score(
        estimator=pipelines[name],
        X=train_data[train_data.columns[2:]],
        y=train_data['target'],
        scoring=scorer,
        n_jobs=-1,
        cv=n_folds,
    )
# Out:
# /home/udimus/env/sber-task/lib/python3.6/site-packages/ipykernel_launcher.py:1: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   """Entry point for launching an IPython kernel.
# HBox(children=(FloatProgress(value=0.0, max=56.0), HTML(value='')))

# %%
scores_df = pd.DataFrame(pipelines_scores).applymap(lambda x: -x)

# %%
scores_df.describe().T
# Out:
#                                                     count          mean  \
# bin:num,prepare:exp,model:cb,metric:our               7.0  2.723525e+03
# bin:num,prepare:exp,model:cb,metric:default           7.0  1.273785e+06
# bin:num,prepare:exp,model:lgbm,metric:our             7.0  2.725612e+03
# bin:num,prepare:exp,model:lgbm,metric:default         7.0  1.226540e+06
# bin:num,prepare:alpha_0,model:cb,metric:our           7.0  2.752941e+03
# bin:num,prepare:alpha_0,model:cb,metric:default       7.0  1.263716e+06
# bin:num,prepare:alpha_0,model:lgbm,metric:our         7.0  2.724017e+03
# bin:num,prepare:alpha_0,model:lgbm,metric:default     7.0  1.207495e+06
# bin:num,prepare:alpha_1,model:cb,metric:our           7.0  2.745216e+03
# bin:num,prepare:alpha_1,model:cb,metric:default       7.0  1.320064e+06
# bin:num,prepare:alpha_1,model:lgbm,metric:our         7.0  2.724165e+03
# bin:num,prepare:alpha_1,model:lgbm,metric:default     7.0  1.209149e+06
# bin:num,prepare:alpha_10,model:cb,metric:our          7.0  2.750286e+03
# bin:num,prepare:alpha_10,model:cb,metric:default      7.0  1.267403e+06
# bin:num,prepare:alpha_10,model:lgbm,metric:our        7.0  2.723758e+03
# bin:num,prepare:alpha_10,model:lgbm,metric:default    7.0  1.218230e+06
# bin:num,prepare:alpha_100,model:cb,metric:our         7.0  2.748868e+03
# bin:num,prepare:alpha_100,model:cb,metric:default     7.0  1.279889e+06
# bin:num,prepare:alpha_100,model:lgbm,metric:our       7.0  2.724145e+03
# bin:num,prepare:alpha_100,model:lgbm,metric:def...    7.0  1.235797e+06
# bin:num,prepare:no,model:cb,metric:our                7.0  2.748022e+03
# bin:num,prepare:no,model:cb,metric:default            7.0  1.249485e+06
# bin:num,prepare:no,model:lgbm,metric:our              7.0  2.732881e+03
# bin:num,prepare:no,model:lgbm,metric:default          7.0  1.211461e+06
# bin:num,prepare:drop,model:cb,metric:our              7.0  2.771265e+03
# bin:num,prepare:drop,model:cb,metric:default          7.0  1.463854e+06
# bin:num,prepare:drop,model:lgbm,metric:our            7.0  2.727177e+03
# bin:num,prepare:drop,model:lgbm,metric:default        7.0  1.366498e+06
# bin:cat,prepare:exp,model:cb,metric:our               7.0  2.710410e+03
# bin:cat,prepare:exp,model:cb,metric:default           7.0  1.303556e+06
# bin:cat,prepare:exp,model:lgbm,metric:our             7.0  2.727564e+03
# bin:cat,prepare:exp,model:lgbm,metric:default         7.0  1.258468e+06
# bin:cat,prepare:alpha_0,model:cb,metric:our           7.0  2.745909e+03
# bin:cat,prepare:alpha_0,model:cb,metric:default       7.0  1.278003e+06
# bin:cat,prepare:alpha_0,model:lgbm,metric:our         7.0  2.724524e+03
# bin:cat,prepare:alpha_0,model:lgbm,metric:default     7.0  1.212290e+06
# bin:cat,prepare:alpha_1,model:cb,metric:our           7.0  2.744811e+03
# bin:cat,prepare:alpha_1,model:cb,metric:default       7.0  1.262476e+06
# bin:cat,prepare:alpha_1,model:lgbm,metric:our         7.0  2.724512e+03
# bin:cat,prepare:alpha_1,model:lgbm,metric:default     7.0  1.216482e+06
# bin:cat,prepare:alpha_10,model:cb,metric:our          7.0  2.744813e+03
# bin:cat,prepare:alpha_10,model:cb,metric:default      7.0  1.264981e+06
# bin:cat,prepare:alpha_10,model:lgbm,metric:our        7.0  2.724488e+03
# bin:cat,prepare:alpha_10,model:lgbm,metric:default    7.0  1.216193e+06
# bin:cat,prepare:alpha_100,model:cb,metric:our         7.0  2.742669e+03
# bin:cat,prepare:alpha_100,model:cb,metric:default     7.0  1.303022e+06
# bin:cat,prepare:alpha_100,model:lgbm,metric:our       7.0  2.724253e+03
# bin:cat,prepare:alpha_100,model:lgbm,metric:def...    7.0  1.242997e+06
# bin:cat,prepare:no,model:cb,metric:our                7.0  2.748485e+03
# bin:cat,prepare:no,model:cb,metric:default            7.0  1.254317e+06
# bin:cat,prepare:no,model:lgbm,metric:our              7.0  2.732881e+03
# bin:cat,prepare:no,model:lgbm,metric:default          7.0  1.211461e+06
# bin:cat,prepare:drop,model:cb,metric:our              7.0  2.769531e+03
# bin:cat,prepare:drop,model:cb,metric:default          7.0  2.059432e+06
# bin:cat,prepare:drop,model:lgbm,metric:our            7.0  2.753995e+03
# bin:cat,prepare:drop,model:lgbm,metric:default        7.0  1.939603e+06
#
#                                                               std  \
# bin:num,prepare:exp,model:cb,metric:our                 30.214774
# bin:num,prepare:exp,model:cb,metric:default          97186.068195
# bin:num,prepare:exp,model:lgbm,metric:our               20.887954
# bin:num,prepare:exp,model:lgbm,metric:default        68778.010103
# bin:num,prepare:alpha_0,model:cb,metric:our             31.088917
# bin:num,prepare:alpha_0,model:cb,metric:default     100006.899397
# bin:num,prepare:alpha_0,model:lgbm,metric:our           22.270102
# bin:num,prepare:alpha_0,model:lgbm,metric:default    58912.976285
# bin:num,prepare:alpha_1,model:cb,metric:our             32.724500
# bin:num,prepare:alpha_1,model:cb,metric:default     180275.085221
# bin:num,prepare:alpha_1,model:lgbm,metric:our           22.472741
# bin:num,prepare:alpha_1,model:lgbm,metric:default    70317.624386
# bin:num,prepare:alpha_10,model:cb,metric:our            24.721632
# bin:num,prepare:alpha_10,model:cb,metric:default     70827.572712
# bin:num,prepare:alpha_10,model:lgbm,metric:our          22.517679
# bin:num,prepare:alpha_10,model:lgbm,metric:default   62225.982944
# bin:num,prepare:alpha_100,model:cb,metric:our           26.522672
# bin:num,prepare:alpha_100,model:cb,metric:default    72620.419887
# bin:num,prepare:alpha_100,model:lgbm,metric:our         22.757996
# bin:num,prepare:alpha_100,model:lgbm,metric:def...   62732.261158
# bin:num,prepare:no,model:cb,metric:our                  23.056952
# bin:num,prepare:no,model:cb,metric:default           75413.092832
# bin:num,prepare:no,model:lgbm,metric:our                22.035058
# bin:num,prepare:no,model:lgbm,metric:default         63123.860174
# bin:num,prepare:drop,model:cb,metric:our                24.106384
# bin:num,prepare:drop,model:cb,metric:default        153530.450714
# bin:num,prepare:drop,model:lgbm,metric:our              18.402281
# bin:num,prepare:drop,model:lgbm,metric:default       39979.172014
# bin:cat,prepare:exp,model:cb,metric:our                 32.742949
# bin:cat,prepare:exp,model:cb,metric:default         117686.479285
# bin:cat,prepare:exp,model:lgbm,metric:our               21.041696
# bin:cat,prepare:exp,model:lgbm,metric:default        67083.414066
# bin:cat,prepare:alpha_0,model:cb,metric:our             30.139295
# bin:cat,prepare:alpha_0,model:cb,metric:default      78820.319036
# bin:cat,prepare:alpha_0,model:lgbm,metric:our           22.608551
# bin:cat,prepare:alpha_0,model:lgbm,metric:default    68571.185009
# bin:cat,prepare:alpha_1,model:cb,metric:our             28.139542
# bin:cat,prepare:alpha_1,model:cb,metric:default      84270.810557
# bin:cat,prepare:alpha_1,model:lgbm,metric:our           21.927598
# bin:cat,prepare:alpha_1,model:lgbm,metric:default    69518.909975
# bin:cat,prepare:alpha_10,model:cb,metric:our            27.921234
# bin:cat,prepare:alpha_10,model:cb,metric:default     95300.690209
# bin:cat,prepare:alpha_10,model:lgbm,metric:our          22.420088
# bin:cat,prepare:alpha_10,model:lgbm,metric:default   56354.453362
# bin:cat,prepare:alpha_100,model:cb,metric:our           28.600283
# bin:cat,prepare:alpha_100,model:cb,metric:default    91533.619379
# bin:cat,prepare:alpha_100,model:lgbm,metric:our         22.495866
# bin:cat,prepare:alpha_100,model:lgbm,metric:def...   64014.031292
# bin:cat,prepare:no,model:cb,metric:our                  23.105777
# bin:cat,prepare:no,model:cb,metric:default           77207.017673
# bin:cat,prepare:no,model:lgbm,metric:our                22.034925
# bin:cat,prepare:no,model:lgbm,metric:default         63123.860174
# bin:cat,prepare:drop,model:cb,metric:our                17.723045
# bin:cat,prepare:drop,model:cb,metric:default        210557.424585
# bin:cat,prepare:drop,model:lgbm,metric:our              21.271324
# bin:cat,prepare:drop,model:lgbm,metric:default       53210.519079
#
#                                                              min  \
# bin:num,prepare:exp,model:cb,metric:our             2.690815e+03
# bin:num,prepare:exp,model:cb,metric:default         1.158812e+06
# bin:num,prepare:exp,model:lgbm,metric:our           2.702406e+03
# bin:num,prepare:exp,model:lgbm,metric:default       1.144889e+06
# bin:num,prepare:alpha_0,model:cb,metric:our         2.715471e+03
# bin:num,prepare:alpha_0,model:cb,metric:default     1.117587e+06
# bin:num,prepare:alpha_0,model:lgbm,metric:our       2.699706e+03
# bin:num,prepare:alpha_0,model:lgbm,metric:default   1.141269e+06
# bin:num,prepare:alpha_1,model:cb,metric:our         2.707549e+03
# bin:num,prepare:alpha_1,model:cb,metric:default     1.185870e+06
# bin:num,prepare:alpha_1,model:lgbm,metric:our       2.700166e+03
# bin:num,prepare:alpha_1,model:lgbm,metric:default   1.126439e+06
# bin:num,prepare:alpha_10,model:cb,metric:our        2.725224e+03
# bin:num,prepare:alpha_10,model:cb,metric:default    1.163044e+06
# bin:num,prepare:alpha_10,model:lgbm,metric:our      2.699766e+03
# bin:num,prepare:alpha_10,model:lgbm,metric:default  1.133427e+06
# bin:num,prepare:alpha_100,model:cb,metric:our       2.721362e+03
# bin:num,prepare:alpha_100,model:cb,metric:default   1.170901e+06
# bin:num,prepare:alpha_100,model:lgbm,metric:our     2.699968e+03
# bin:num,prepare:alpha_100,model:lgbm,metric:def...  1.142514e+06
# bin:num,prepare:no,model:cb,metric:our              2.709252e+03
# bin:num,prepare:no,model:cb,metric:default          1.157864e+06
# bin:num,prepare:no,model:lgbm,metric:our            2.708380e+03
# bin:num,prepare:no,model:lgbm,metric:default        1.120185e+06
# bin:num,prepare:drop,model:cb,metric:our            2.742892e+03
# bin:num,prepare:drop,model:cb,metric:default        1.362133e+06
# bin:num,prepare:drop,model:lgbm,metric:our          2.706792e+03
# bin:num,prepare:drop,model:lgbm,metric:default      1.320989e+06
# bin:cat,prepare:exp,model:cb,metric:our             2.671289e+03
# bin:cat,prepare:exp,model:cb,metric:default         1.173823e+06
# bin:cat,prepare:exp,model:lgbm,metric:our           2.703426e+03
# bin:cat,prepare:exp,model:lgbm,metric:default       1.167833e+06
# bin:cat,prepare:alpha_0,model:cb,metric:our         2.709593e+03
# bin:cat,prepare:alpha_0,model:cb,metric:default     1.164333e+06
# bin:cat,prepare:alpha_0,model:lgbm,metric:our       2.700217e+03
# bin:cat,prepare:alpha_0,model:lgbm,metric:default   1.132834e+06
# bin:cat,prepare:alpha_1,model:cb,metric:our         2.705435e+03
# bin:cat,prepare:alpha_1,model:cb,metric:default     1.147873e+06
# bin:cat,prepare:alpha_1,model:lgbm,metric:our       2.700604e+03
# bin:cat,prepare:alpha_1,model:lgbm,metric:default   1.119810e+06
# bin:cat,prepare:alpha_10,model:cb,metric:our        2.703958e+03
# bin:cat,prepare:alpha_10,model:cb,metric:default    1.162546e+06
# bin:cat,prepare:alpha_10,model:lgbm,metric:our      2.700126e+03
# bin:cat,prepare:alpha_10,model:lgbm,metric:default  1.139536e+06
# bin:cat,prepare:alpha_100,model:cb,metric:our       2.709650e+03
# bin:cat,prepare:alpha_100,model:cb,metric:default   1.174392e+06
# bin:cat,prepare:alpha_100,model:lgbm,metric:our     2.700272e+03
# bin:cat,prepare:alpha_100,model:lgbm,metric:def...  1.144668e+06
# bin:cat,prepare:no,model:cb,metric:our              2.709252e+03
# bin:cat,prepare:no,model:cb,metric:default          1.157864e+06
# bin:cat,prepare:no,model:lgbm,metric:our            2.708380e+03
# bin:cat,prepare:no,model:lgbm,metric:default        1.120185e+06
# bin:cat,prepare:drop,model:cb,metric:our            2.748435e+03
# bin:cat,prepare:drop,model:cb,metric:default        1.916837e+06
# bin:cat,prepare:drop,model:lgbm,metric:our          2.729212e+03
# bin:cat,prepare:drop,model:lgbm,metric:default      1.879225e+06
#
#                                                              25%  \
# bin:num,prepare:exp,model:cb,metric:our             2.700037e+03
# bin:num,prepare:exp,model:cb,metric:default         1.221359e+06
# bin:num,prepare:exp,model:lgbm,metric:our           2.706794e+03
# bin:num,prepare:exp,model:lgbm,metric:default       1.164473e+06
# bin:num,prepare:alpha_0,model:cb,metric:our         2.727547e+03
# bin:num,prepare:alpha_0,model:cb,metric:default     1.198391e+06
# bin:num,prepare:alpha_0,model:lgbm,metric:our       2.703539e+03
# bin:num,prepare:alpha_0,model:lgbm,metric:default   1.154280e+06
# bin:num,prepare:alpha_1,model:cb,metric:our         2.714660e+03
# bin:num,prepare:alpha_1,model:cb,metric:default     1.209692e+06
# bin:num,prepare:alpha_1,model:lgbm,metric:our       2.702853e+03
# bin:num,prepare:alpha_1,model:lgbm,metric:default   1.144755e+06
# bin:num,prepare:alpha_10,model:cb,metric:our        2.728407e+03
# bin:num,prepare:alpha_10,model:cb,metric:default    1.224725e+06
# bin:num,prepare:alpha_10,model:lgbm,metric:our      2.702569e+03
# bin:num,prepare:alpha_10,model:lgbm,metric:default  1.165881e+06
# bin:num,prepare:alpha_100,model:cb,metric:our       2.727500e+03
# bin:num,prepare:alpha_100,model:cb,metric:default   1.240640e+06
# bin:num,prepare:alpha_100,model:lgbm,metric:our     2.702492e+03
# bin:num,prepare:alpha_100,model:lgbm,metric:def...  1.188112e+06
# bin:num,prepare:no,model:cb,metric:our              2.736650e+03
# bin:num,prepare:no,model:cb,metric:default          1.201249e+06
# bin:num,prepare:no,model:lgbm,metric:our            2.716223e+03
# bin:num,prepare:no,model:lgbm,metric:default        1.163834e+06
# bin:num,prepare:drop,model:cb,metric:our            2.753338e+03
# bin:num,prepare:drop,model:cb,metric:default        1.389690e+06
# bin:num,prepare:drop,model:lgbm,metric:our          2.710257e+03
# bin:num,prepare:drop,model:lgbm,metric:default      1.342074e+06
# bin:cat,prepare:exp,model:cb,metric:our             2.683202e+03
# bin:cat,prepare:exp,model:cb,metric:default         1.224445e+06
# bin:cat,prepare:exp,model:lgbm,metric:our           2.709091e+03
# bin:cat,prepare:exp,model:lgbm,metric:default       1.200793e+06
# bin:cat,prepare:alpha_0,model:cb,metric:our         2.719734e+03
# bin:cat,prepare:alpha_0,model:cb,metric:default     1.230324e+06
# bin:cat,prepare:alpha_0,model:lgbm,metric:our       2.703124e+03
# bin:cat,prepare:alpha_0,model:lgbm,metric:default   1.149166e+06
# bin:cat,prepare:alpha_1,model:cb,metric:our         2.723254e+03
# bin:cat,prepare:alpha_1,model:cb,metric:default     1.211224e+06
# bin:cat,prepare:alpha_1,model:lgbm,metric:our       2.704211e+03
# bin:cat,prepare:alpha_1,model:lgbm,metric:default   1.161770e+06
# bin:cat,prepare:alpha_10,model:cb,metric:our        2.724341e+03
# bin:cat,prepare:alpha_10,model:cb,metric:default    1.196983e+06
# bin:cat,prepare:alpha_10,model:lgbm,metric:our      2.703829e+03
# bin:cat,prepare:alpha_10,model:lgbm,metric:default  1.168119e+06
# bin:cat,prepare:alpha_100,model:cb,metric:our       2.714404e+03
# bin:cat,prepare:alpha_100,model:cb,metric:default   1.229114e+06
# bin:cat,prepare:alpha_100,model:lgbm,metric:our     2.703160e+03
# bin:cat,prepare:alpha_100,model:lgbm,metric:def...  1.198093e+06
# bin:cat,prepare:no,model:cb,metric:our              2.738317e+03
# bin:cat,prepare:no,model:cb,metric:default          1.201249e+06
# bin:cat,prepare:no,model:lgbm,metric:our            2.716224e+03
# bin:cat,prepare:no,model:lgbm,metric:default        1.163834e+06
# bin:cat,prepare:drop,model:cb,metric:our            2.757191e+03
# bin:cat,prepare:drop,model:cb,metric:default        1.951143e+06
# bin:cat,prepare:drop,model:lgbm,metric:our          2.739365e+03
# bin:cat,prepare:drop,model:lgbm,metric:default      1.914158e+06
#
#                                                              50%  \
# bin:num,prepare:exp,model:cb,metric:our             2.713438e+03
# bin:num,prepare:exp,model:cb,metric:default         1.226264e+06
# bin:num,prepare:exp,model:lgbm,metric:our           2.726786e+03
# bin:num,prepare:exp,model:lgbm,metric:default       1.244009e+06
# bin:num,prepare:alpha_0,model:cb,metric:our         2.754355e+03
# bin:num,prepare:alpha_0,model:cb,metric:default     1.268033e+06
# bin:num,prepare:alpha_0,model:lgbm,metric:our       2.725047e+03
# bin:num,prepare:alpha_0,model:lgbm,metric:default   1.217154e+06
# bin:num,prepare:alpha_1,model:cb,metric:our         2.756087e+03
# bin:num,prepare:alpha_1,model:cb,metric:default     1.281181e+06
# bin:num,prepare:alpha_1,model:lgbm,metric:our       2.725597e+03
# bin:num,prepare:alpha_1,model:lgbm,metric:default   1.223124e+06
# bin:num,prepare:alpha_10,model:cb,metric:our        2.750725e+03
# bin:num,prepare:alpha_10,model:cb,metric:default    1.262073e+06
# bin:num,prepare:alpha_10,model:lgbm,metric:our      2.725366e+03
# bin:num,prepare:alpha_10,model:lgbm,metric:default  1.246930e+06
# bin:num,prepare:alpha_100,model:cb,metric:our       2.740780e+03
# bin:num,prepare:alpha_100,model:cb,metric:default   1.259264e+06
# bin:num,prepare:alpha_100,model:lgbm,metric:our     2.727374e+03
# bin:num,prepare:alpha_100,model:lgbm,metric:def...  1.267582e+06
# bin:num,prepare:no,model:cb,metric:our              2.758205e+03
# bin:num,prepare:no,model:cb,metric:default          1.252621e+06
# bin:num,prepare:no,model:lgbm,metric:our            2.724278e+03
# bin:num,prepare:no,model:lgbm,metric:default        1.229687e+06
# bin:num,prepare:drop,model:cb,metric:our            2.761669e+03
# bin:num,prepare:drop,model:cb,metric:default        1.395180e+06
# bin:num,prepare:drop,model:lgbm,metric:our          2.729700e+03
# bin:num,prepare:drop,model:lgbm,metric:default      1.364839e+06
# bin:cat,prepare:exp,model:cb,metric:our             2.706966e+03
# bin:cat,prepare:exp,model:cb,metric:default         1.258180e+06
# bin:cat,prepare:exp,model:lgbm,metric:our           2.725643e+03
# bin:cat,prepare:exp,model:lgbm,metric:default       1.279719e+06
# bin:cat,prepare:alpha_0,model:cb,metric:our         2.753351e+03
# bin:cat,prepare:alpha_0,model:cb,metric:default     1.278669e+06
# bin:cat,prepare:alpha_0,model:lgbm,metric:our       2.725627e+03
# bin:cat,prepare:alpha_0,model:lgbm,metric:default   1.229955e+06
# bin:cat,prepare:alpha_1,model:cb,metric:our         2.752724e+03
# bin:cat,prepare:alpha_1,model:cb,metric:default     1.239755e+06
# bin:cat,prepare:alpha_1,model:lgbm,metric:our       2.725024e+03
# bin:cat,prepare:alpha_1,model:lgbm,metric:default   1.225806e+06
# bin:cat,prepare:alpha_10,model:cb,metric:our        2.754657e+03
# bin:cat,prepare:alpha_10,model:cb,metric:default    1.248703e+06
# bin:cat,prepare:alpha_10,model:lgbm,metric:our      2.724877e+03
# bin:cat,prepare:alpha_10,model:lgbm,metric:default  1.245364e+06
# bin:cat,prepare:alpha_100,model:cb,metric:our       2.756333e+03
# bin:cat,prepare:alpha_100,model:cb,metric:default   1.331871e+06
# bin:cat,prepare:alpha_100,model:lgbm,metric:our     2.727823e+03
# bin:cat,prepare:alpha_100,model:lgbm,metric:def...  1.261479e+06
# bin:cat,prepare:no,model:cb,metric:our              2.758241e+03
# bin:cat,prepare:no,model:cb,metric:default          1.252621e+06
# bin:cat,prepare:no,model:lgbm,metric:our            2.724278e+03
# bin:cat,prepare:no,model:lgbm,metric:default        1.229687e+06
# bin:cat,prepare:drop,model:cb,metric:our            2.761700e+03
# bin:cat,prepare:drop,model:cb,metric:default        1.988017e+06
# bin:cat,prepare:drop,model:lgbm,metric:our          2.744604e+03
# bin:cat,prepare:drop,model:lgbm,metric:default      1.930972e+06
#
#                                                              75%           max
# bin:num,prepare:exp,model:cb,metric:our             2.744310e+03  2.771730e+03
# bin:num,prepare:exp,model:cb,metric:default         1.321857e+06  1.444987e+06
# bin:num,prepare:exp,model:lgbm,metric:our           2.742556e+03  2.751390e+03
# bin:num,prepare:exp,model:lgbm,metric:default       1.276138e+06  1.315657e+06
# bin:num,prepare:alpha_0,model:cb,metric:our         2.775736e+03  2.794193e+03
# bin:num,prepare:alpha_0,model:cb,metric:default     1.330064e+06  1.403482e+06
# bin:num,prepare:alpha_0,model:lgbm,metric:our       2.742627e+03  2.751036e+03
# bin:num,prepare:alpha_0,model:lgbm,metric:default   1.246090e+06  1.293306e+06
# bin:num,prepare:alpha_1,model:cb,metric:our         2.766434e+03  2.790687e+03
# bin:num,prepare:alpha_1,model:cb,metric:default     1.322704e+06  1.708605e+06
# bin:num,prepare:alpha_1,model:lgbm,metric:our       2.743519e+03  2.750652e+03
# bin:num,prepare:alpha_1,model:lgbm,metric:default   1.262226e+06  1.300515e+06
# bin:num,prepare:alpha_10,model:cb,metric:our        2.764112e+03  2.791015e+03
# bin:num,prepare:alpha_10,model:cb,metric:default    1.311558e+06  1.374140e+06
# bin:num,prepare:alpha_10,model:lgbm,metric:our      2.742450e+03  2.751135e+03
# bin:num,prepare:alpha_10,model:lgbm,metric:default  1.261972e+06  1.291548e+06
# bin:num,prepare:alpha_100,model:cb,metric:our       2.768255e+03  2.788423e+03
# bin:num,prepare:alpha_100,model:cb,metric:default   1.340139e+06  1.367501e+06
# bin:num,prepare:alpha_100,model:lgbm,metric:our     2.742620e+03  2.751450e+03
# bin:num,prepare:alpha_100,model:lgbm,metric:def...  1.280567e+06  1.303125e+06
# bin:num,prepare:no,model:cb,metric:our              2.760299e+03  2.774801e+03
# bin:num,prepare:no,model:cb,metric:default          1.272541e+06  1.388328e+06
# bin:num,prepare:no,model:lgbm,metric:our            2.751764e+03  2.761534e+03
# bin:num,prepare:no,model:lgbm,metric:default        1.255108e+06  1.292474e+06
# bin:num,prepare:drop,model:cb,metric:our            2.792258e+03  2.803102e+03
# bin:num,prepare:drop,model:cb,metric:default        1.453659e+06  1.802966e+06
# bin:num,prepare:drop,model:lgbm,metric:our          2.741807e+03  2.749615e+03
# bin:num,prepare:drop,model:lgbm,metric:default      1.377035e+06  1.441442e+06
# bin:cat,prepare:exp,model:cb,metric:our             2.736883e+03  2.754447e+03
# bin:cat,prepare:exp,model:cb,metric:default         1.370519e+06  1.502963e+06
# bin:cat,prepare:exp,model:lgbm,metric:our           2.746857e+03  2.751980e+03
# bin:cat,prepare:exp,model:lgbm,metric:default       1.317012e+06  1.326114e+06
# bin:cat,prepare:alpha_0,model:cb,metric:our         2.766325e+03  2.786302e+03
# bin:cat,prepare:alpha_0,model:cb,metric:default     1.319073e+06  1.404225e+06
# bin:cat,prepare:alpha_0,model:lgbm,metric:our       2.744336e+03  2.750903e+03
# bin:cat,prepare:alpha_0,model:lgbm,metric:default   1.260238e+06  1.304436e+06
# bin:cat,prepare:alpha_1,model:cb,metric:our         2.764305e+03  2.780398e+03
# bin:cat,prepare:alpha_1,model:cb,metric:default     1.319132e+06  1.388989e+06
# bin:cat,prepare:alpha_1,model:lgbm,metric:our       2.743477e+03  2.750580e+03
# bin:cat,prepare:alpha_1,model:lgbm,metric:default   1.276185e+06  1.293848e+06
# bin:cat,prepare:alpha_10,model:cb,metric:our        2.765639e+03  2.775116e+03
# bin:cat,prepare:alpha_10,model:cb,metric:default    1.303891e+06  1.441869e+06
# bin:cat,prepare:alpha_10,model:lgbm,metric:our      2.743687e+03  2.751385e+03
# bin:cat,prepare:alpha_10,model:lgbm,metric:default  1.259398e+06  1.273416e+06
# bin:cat,prepare:alpha_100,model:cb,metric:our       2.765833e+03  2.772224e+03
# bin:cat,prepare:alpha_100,model:cb,metric:default   1.372137e+06  1.412391e+06
# bin:cat,prepare:alpha_100,model:lgbm,metric:our     2.741562e+03  2.752229e+03
# bin:cat,prepare:alpha_100,model:lgbm,metric:def...  1.296588e+06  1.305472e+06
# bin:cat,prepare:no,model:cb,metric:our              2.760235e+03  2.774801e+03
# bin:cat,prepare:no,model:cb,metric:default          1.289455e+06  1.388328e+06
# bin:cat,prepare:no,model:lgbm,metric:our            2.751764e+03  2.761534e+03
# bin:cat,prepare:no,model:lgbm,metric:default        1.255108e+06  1.292474e+06
# bin:cat,prepare:drop,model:cb,metric:our            2.784871e+03  2.792460e+03
# bin:cat,prepare:drop,model:cb,metric:default        2.044651e+06  2.519581e+06
# bin:cat,prepare:drop,model:lgbm,metric:our          2.769444e+03  2.786529e+03
# bin:cat,prepare:drop,model:lgbm,metric:default      1.946322e+06  2.046067e+06

# %%
scores_mean_df = (
    pd
    .DataFrame(scores_df.T.mean(axis=1))
    .reset_index(drop=False)
    .rename(columns={'index': 'name', 0: 'mean_score'}))

# %%
columns = ['bin', 'prepare', 'model', 'metric']

# %%
def get_pipeline_type(name, level):
    pipeline_types = [level_value.split(':')
                      for level_value in name.split(',')]
    pipeline_types = {level_value[0]: level_value[1]
                      for level_value in pipeline_types}
    return pipeline_types.get(level)

# %%
for col in columns:
    scores_mean_df[col] = scores_mean_df['name'].apply(lambda x: get_pipeline_type(x, col))

# %% [markdown]
# #### Функция потерь

# %%
scores_mean_df.groupby(by='metric')['mean_score'].describe()
# Out:
#          count          mean            std           min           25%  \
# metric
# default   28.0  1.314880e+06  201651.662458  1.207495e+06  1.217793e+06
# our       28.0  2.737169e+03      15.139612  2.710410e+03  2.724430e+03
#
#                   50%           75%           max
# metric
# default  1.260472e+06  1.285672e+06  2.059432e+06
# our      2.732881e+03  2.748138e+03  2.771265e+03

# %% [markdown]
# Мы видим, что при использовании не нашей метрики при оптимизации (а MSE) всё совсем плохо (из-за тяжёлого хвоста).

# %%
scores_mean_best_df = scores_mean_df[scores_mean_df['metric']=='our'].copy()

# %% [markdown]
# #### Обработка бинарных признаков

# %%
scores_mean_best_df.groupby(by='bin')['mean_score'].describe()
# Out:
#      count         mean        std         min          25%          50%  \
# bin
# cat   14.0  2737.060348  15.581563  2710.41017  2724.514965  2737.774911
# num   14.0  2737.276967  15.272088  2723.52526  2724.150170  2730.028778
#
#              75%          max
# bin
# cat  2745.635090  2769.531453
# num  2748.656592  2771.264858

# %% [markdown]
# Разницы никакой.

# %% [markdown]
# #### Модель и подготовка признаков

# %%
scores_mean_best_df.groupby(by='model')['mean_score'].describe()
# Out:
#        count         mean        std          min         25%          50%  \
# model
# cb      14.0  2746.196518  15.349337  2710.410170  2744.81128  2746.965600
# lgbm    14.0  2728.140796   8.056149  2723.758005  2724.18724  2724.517892
#
#                75%          max
# model
# cb     2749.931475  2771.264858
# lgbm   2727.466756  2753.994763

# %%
scores_mean_best_df.groupby(by='prepare')['mean_score'].describe()
# Out:
#            count         mean        std          min          25%  \
# prepare
# alpha_0      4.0  2736.847609  14.805317  2724.017091  2724.397082
# alpha_1      4.0  2734.676007  11.938445  2724.165421  2724.425384
# alpha_10     4.0  2735.836401  13.711750  2723.758005  2724.305833
# alpha_100    4.0  2734.983621  12.707793  2724.145087  2724.225792
# drop         4.0  2755.491895  20.411584  2727.176505  2747.290199
# exp          4.0  2721.777636   7.755624  2710.410170  2720.246487
# no           4.0  2740.567432   8.877403  2732.881050  2732.881155
#
#                    50%          75%          max
# prepare
# alpha_0    2735.216397  2747.666924  2752.940550
# alpha_1    2734.661336  2744.911959  2745.215932
# alpha_10   2734.650828  2746.181395  2750.285943
# alpha_100  2733.460663  2744.218492  2748.868073
# drop       2761.763108  2769.964804  2771.264858
# exp        2724.568434  2726.099583  2727.563507
# no         2740.451670  2748.137948  2748.485337

# %%
scores_mean_best_df.sort_values(by='mean_score', ascending=True)
# Out:
#                                                name   mean_score  bin  \
# 28          bin:cat,prepare:exp,model:cb,metric:our  2710.410170  cat
# 0           bin:num,prepare:exp,model:cb,metric:our  2723.525260  num
# 14   bin:num,prepare:alpha_10,model:lgbm,metric:our  2723.758005  num
# 6     bin:num,prepare:alpha_0,model:lgbm,metric:our  2724.017091  num
# 18  bin:num,prepare:alpha_100,model:lgbm,metric:our  2724.145087  num
# 10    bin:num,prepare:alpha_1,model:lgbm,metric:our  2724.165421  num
# 46  bin:cat,prepare:alpha_100,model:lgbm,metric:our  2724.252694  cat
# 42   bin:cat,prepare:alpha_10,model:lgbm,metric:our  2724.488442  cat
# 38    bin:cat,prepare:alpha_1,model:lgbm,metric:our  2724.512038  cat
# 34    bin:cat,prepare:alpha_0,model:lgbm,metric:our  2724.523746  cat
# 2         bin:num,prepare:exp,model:lgbm,metric:our  2725.611608  num
# 26       bin:num,prepare:drop,model:lgbm,metric:our  2727.176505  num
# 30        bin:cat,prepare:exp,model:lgbm,metric:our  2727.563507  cat
# 22         bin:num,prepare:no,model:lgbm,metric:our  2732.881050  num
# 50         bin:cat,prepare:no,model:lgbm,metric:our  2732.881189  cat
# 44    bin:cat,prepare:alpha_100,model:cb,metric:our  2742.668632  cat
# 36      bin:cat,prepare:alpha_1,model:cb,metric:our  2744.810635  cat
# 40     bin:cat,prepare:alpha_10,model:cb,metric:our  2744.813213  cat
# 8       bin:num,prepare:alpha_1,model:cb,metric:our  2745.215932  num
# 32      bin:cat,prepare:alpha_0,model:cb,metric:our  2745.909049  cat
# 20           bin:num,prepare:no,model:cb,metric:our  2748.022152  num
# 48           bin:cat,prepare:no,model:cb,metric:our  2748.485337  cat
# 16    bin:num,prepare:alpha_100,model:cb,metric:our  2748.868073  num
# 12     bin:num,prepare:alpha_10,model:cb,metric:our  2750.285943  num
# 4       bin:num,prepare:alpha_0,model:cb,metric:our  2752.940550  num
# 54       bin:cat,prepare:drop,model:lgbm,metric:our  2753.994763  cat
# 52         bin:cat,prepare:drop,model:cb,metric:our  2769.531453  cat
# 24         bin:num,prepare:drop,model:cb,metric:our  2771.264858  num
#
#       prepare model metric
# 28        exp    cb    our
# 0         exp    cb    our
# 14   alpha_10  lgbm    our
# 6     alpha_0  lgbm    our
# 18  alpha_100  lgbm    our
# 10    alpha_1  lgbm    our
# 46  alpha_100  lgbm    our
# 42   alpha_10  lgbm    our
# 38    alpha_1  lgbm    our
# 34    alpha_0  lgbm    our
# 2         exp  lgbm    our
# 26       drop  lgbm    our
# 30        exp  lgbm    our
# 22         no  lgbm    our
# 50         no  lgbm    our
# 44  alpha_100    cb    our
# 36    alpha_1    cb    our
# 40   alpha_10    cb    our
# 8     alpha_1    cb    our
# 32    alpha_0    cb    our
# 20         no    cb    our
# 48         no    cb    our
# 16  alpha_100    cb    our
# 12   alpha_10    cb    our
# 4     alpha_0    cb    our
# 54       drop  lgbm    our
# 52       drop    cb    our
# 24       drop    cb    our

# %% [markdown]
# Разброс не очень велик и сравним с разнице между фолдами. Но выберем лучший вариант.

# %%
scores_mean_best_df['with_preproc'] = scores_mean_best_df['prepare'].apply(lambda x: x not in ['no', 'drop'])

# %%
best_pipelines = (
    scores_mean_best_df
    .groupby(by=['model', 'with_preproc'], as_index=False)
    .apply(lambda x: x.sort_values(by='mean_score').head(1)))

# %%
best_pipelines
# Out:
#                                                 name   mean_score  bin  \
# 0 20          bin:num,prepare:no,model:cb,metric:our  2748.022152  num
# 1 28         bin:cat,prepare:exp,model:cb,metric:our  2710.410170  cat
# 2 26      bin:num,prepare:drop,model:lgbm,metric:our  2727.176505  num
# 3 14  bin:num,prepare:alpha_10,model:lgbm,metric:our  2723.758005  num
#
#        prepare model metric  with_preproc
# 0 20        no    cb    our         False
# 1 28       exp    cb    our          True
# 2 26      drop  lgbm    our         False
# 3 14  alpha_10  lgbm    our          True

# %% [markdown]
# # Получение предсказаний
# Итак, выберем 4 лучших модели -- lgbm, cb, с предобработкой и без.

# %%
final_pipelines = {
    'cb_with_preproc': Pipeline([
        ('bin_transform', BinFeaturesTransformer(bin_as_numeric=False)),
        ('cat_transform', CatFeaturesTransformer(
            cat_features=bin_as_cat_features['cat_features'],
            expanding=True,
            alpha=0,
        )),
        ('regressor', CatboostWrapper(
            n_estimators=100,
            loss_function=OurLossCBObjective(),
            eval_metric=OurLossCBMetric(),
        )),
    ]),
    'cb': Pipeline([
        ('bin_transform', BinFeaturesTransformer(bin_as_numeric=True)),
        ('regressor', CatboostWrapper(
            n_estimators=100,
            cat_features=bin_as_num_features['cat_features'],
            loss_function=OurLossCBObjective(),
            eval_metric=OurLossCBMetric(),
        )),
    ]),
    'lgbm_with_preproc': Pipeline([
        ('bin_transform', BinFeaturesTransformer(bin_as_numeric=True)),
        ('cat_transform', CatFeaturesTransformer(
            cat_features=bin_as_num_features['cat_features'],
            expanding=False,
            alpha=10,
        )),
        ('regressor', LightgbmWrapper(
            n_estimators=100,
            objective=our_loss_lgbm_objective,
        )),
    ]),
    'lgbm': Pipeline([
        ('bin_transform', BinFeaturesTransformer(bin_as_numeric=True)),
        ('drop_transform', DropTransformer(
            drop_columns=bin_as_num_features['cat_features']
        )),
        ('regressor', LightgbmWrapper(
            n_estimators=100,
            objective=our_loss_lgbm_objective,
        )),
    ]),
}

# %%
for name in final_pipelines:
    logger.info(f'Training of {name}')
    final_pipelines[name].fit(
        X=train_data[train_data.columns[2:]],
        y=train_data['target'],
    )
# Out:
# 2020-05-16 22:57:26,938 INFO:<ipython-input-15-c052d415860f> Training of cb_with_preproc
# 0:	learn: 2917.2320868	total: 186ms	remaining: 18.4s
# 1:	learn: 2883.9070921	total: 323ms	remaining: 15.8s
# 2:	learn: 2870.8287182	total: 460ms	remaining: 14.9s
# 3:	learn: 2859.5051747	total: 591ms	remaining: 14.2s
# 4:	learn: 2850.9599050	total: 731ms	remaining: 13.9s
# 5:	learn: 2843.7570431	total: 862ms	remaining: 13.5s
# 6:	learn: 2837.0634626	total: 996ms	remaining: 13.2s
# 7:	learn: 2831.5042679	total: 1.13s	remaining: 13s
# 8:	learn: 2823.4010622	total: 1.26s	remaining: 12.8s
# 9:	learn: 2818.5723454	total: 1.4s	remaining: 12.6s
# 10:	learn: 2814.1595940	total: 1.53s	remaining: 12.4s
# 11:	learn: 2809.7272746	total: 1.66s	remaining: 12.2s
# 12:	learn: 2806.4218708	total: 1.79s	remaining: 12s
# 13:	learn: 2802.3048802	total: 1.93s	remaining: 11.9s
# 14:	learn: 2797.6381890	total: 2.06s	remaining: 11.7s
# 15:	learn: 2794.9436923	total: 2.2s	remaining: 11.5s
# 16:	learn: 2791.3134629	total: 2.33s	remaining: 11.4s
# 17:	learn: 2788.8661155	total: 2.46s	remaining: 11.2s
# 18:	learn: 2785.7323201	total: 2.6s	remaining: 11.1s
# 19:	learn: 2781.8212384	total: 2.73s	remaining: 10.9s
# 20:	learn: 2778.2438658	total: 2.87s	remaining: 10.8s
# 21:	learn: 2775.8552918	total: 3.01s	remaining: 10.7s
# 22:	learn: 2773.0904505	total: 3.15s	remaining: 10.5s
# 23:	learn: 2771.6628748	total: 3.29s	remaining: 10.4s
# 24:	learn: 2769.5258995	total: 3.42s	remaining: 10.3s
# 25:	learn: 2767.8823151	total: 3.56s	remaining: 10.1s
# 26:	learn: 2765.5180510	total: 3.69s	remaining: 9.97s
# 27:	learn: 2763.1890785	total: 3.82s	remaining: 9.83s
# 28:	learn: 2761.2494070	total: 3.96s	remaining: 9.7s
# 29:	learn: 2759.4643413	total: 4.09s	remaining: 9.54s
# 30:	learn: 2757.7462478	total: 4.22s	remaining: 9.4s
# 31:	learn: 2756.2117379	total: 4.36s	remaining: 9.26s
# 32:	learn: 2754.8574235	total: 4.49s	remaining: 9.12s
# 33:	learn: 2752.9427506	total: 4.62s	remaining: 8.98s
# 34:	learn: 2751.2000793	total: 4.76s	remaining: 8.84s
# 35:	learn: 2749.5126406	total: 4.89s	remaining: 8.7s
# 36:	learn: 2748.1490362	total: 5.03s	remaining: 8.56s
# 37:	learn: 2746.9976670	total: 5.26s	remaining: 8.59s
# 38:	learn: 2744.0284041	total: 5.39s	remaining: 8.44s
# 39:	learn: 2743.1529726	total: 5.53s	remaining: 8.3s
# 40:	learn: 2741.2241910	total: 5.66s	remaining: 8.15s
# 41:	learn: 2739.5931001	total: 5.79s	remaining: 8s
# 42:	learn: 2738.1357852	total: 5.92s	remaining: 7.86s
# 43:	learn: 2735.4130963	total: 6.07s	remaining: 7.72s
# 44:	learn: 2734.2854447	total: 6.2s	remaining: 7.57s
# 45:	learn: 2732.8733705	total: 6.33s	remaining: 7.43s
# 46:	learn: 2732.2648464	total: 6.46s	remaining: 7.29s
# 47:	learn: 2731.8498664	total: 6.6s	remaining: 7.15s
# 48:	learn: 2730.8046068	total: 6.73s	remaining: 7.01s
# 49:	learn: 2729.3119330	total: 6.87s	remaining: 6.87s
# 50:	learn: 2728.6208592	total: 7s	remaining: 6.72s
# 51:	learn: 2727.6744006	total: 7.13s	remaining: 6.58s
# 52:	learn: 2726.0767445	total: 7.26s	remaining: 6.44s
# 53:	learn: 2725.1803710	total: 7.4s	remaining: 6.3s
# 54:	learn: 2723.8415626	total: 7.53s	remaining: 6.16s
# 55:	learn: 2723.2151117	total: 7.66s	remaining: 6.02s
# 56:	learn: 2722.5701261	total: 7.79s	remaining: 5.88s
# 57:	learn: 2721.3998007	total: 7.93s	remaining: 5.74s
# 58:	learn: 2720.5424541	total: 8.06s	remaining: 5.6s
# 59:	learn: 2718.7499258	total: 8.19s	remaining: 5.46s
# 60:	learn: 2717.5777161	total: 8.33s	remaining: 5.32s
# 61:	learn: 2716.7008427	total: 8.46s	remaining: 5.19s
# 62:	learn: 2716.0273665	total: 8.6s	remaining: 5.05s
# 63:	learn: 2715.3833037	total: 8.73s	remaining: 4.91s
# 64:	learn: 2714.4888944	total: 8.86s	remaining: 4.77s
# 65:	learn: 2713.0281577	total: 9s	remaining: 4.63s
# 66:	learn: 2711.9365620	total: 9.14s	remaining: 4.5s
# 67:	learn: 2711.0195543	total: 9.27s	remaining: 4.36s
# 68:	learn: 2710.5360286	total: 9.4s	remaining: 4.22s
# 69:	learn: 2709.6030119	total: 9.54s	remaining: 4.09s
# 70:	learn: 2709.1004832	total: 9.67s	remaining: 3.95s
# 71:	learn: 2708.2926185	total: 9.81s	remaining: 3.81s
# 72:	learn: 2707.5694297	total: 9.94s	remaining: 3.68s
# 73:	learn: 2706.7778356	total: 10.1s	remaining: 3.54s
# 74:	learn: 2706.3491864	total: 10.2s	remaining: 3.4s
# 75:	learn: 2705.7700620	total: 10.3s	remaining: 3.26s
# 76:	learn: 2705.0926661	total: 10.5s	remaining: 3.13s
# 77:	learn: 2704.1897092	total: 10.6s	remaining: 2.99s
# 78:	learn: 2703.7985640	total: 10.7s	remaining: 2.85s
# 79:	learn: 2702.9684637	total: 10.9s	remaining: 2.72s
# 80:	learn: 2702.5623418	total: 11s	remaining: 2.58s
# 81:	learn: 2701.5992191	total: 11.1s	remaining: 2.44s
# 82:	learn: 2700.8451068	total: 11.3s	remaining: 2.31s
# 83:	learn: 2700.0670805	total: 11.4s	remaining: 2.17s
# 84:	learn: 2699.6203082	total: 11.5s	remaining: 2.04s
# 85:	learn: 2699.3145950	total: 11.7s	remaining: 1.9s
# 86:	learn: 2698.7816009	total: 11.8s	remaining: 1.76s
# 87:	learn: 2698.1907274	total: 11.9s	remaining: 1.63s
# 88:	learn: 2697.5515351	total: 12.1s	remaining: 1.49s
# 89:	learn: 2697.2630208	total: 12.2s	remaining: 1.36s
# 90:	learn: 2696.8591049	total: 12.3s	remaining: 1.22s
# 91:	learn: 2695.9146513	total: 12.5s	remaining: 1.08s
# 92:	learn: 2695.0840760	total: 12.6s	remaining: 949ms
# 93:	learn: 2694.6028311	total: 12.7s	remaining: 813ms
# 94:	learn: 2693.8442720	total: 12.9s	remaining: 677ms
# 95:	learn: 2693.7565840	total: 13s	remaining: 542ms
# 96:	learn: 2693.2499882	total: 13.1s	remaining: 406ms
# 97:	learn: 2692.8020219	total: 13.3s	remaining: 271ms
# 98:	learn: 2692.4367524	total: 13.4s	remaining: 135ms
# 2020-05-16 22:58:01,298 INFO:<ipython-input-15-c052d415860f> Training of cb
# 99:	learn: 2691.9039336	total: 13.5s	remaining: 0us
# 0:	learn: 9501.3643520	total: 269ms	remaining: 26.6s
# 1:	learn: 9226.5072558	total: 546ms	remaining: 26.8s
# 2:	learn: 8959.2895905	total: 771ms	remaining: 24.9s
# 3:	learn: 8707.4267903	total: 1.01s	remaining: 24.3s
# 4:	learn: 8462.4326075	total: 1.26s	remaining: 24s
# 5:	learn: 8231.2437359	total: 1.51s	remaining: 23.6s
# 6:	learn: 8013.2934327	total: 1.75s	remaining: 23.2s
# 7:	learn: 7802.0284362	total: 2s	remaining: 22.9s
# 8:	learn: 7599.1926659	total: 2.23s	remaining: 22.5s
# 9:	learn: 7407.3837333	total: 2.47s	remaining: 22.2s
# 10:	learn: 7222.3932921	total: 2.71s	remaining: 21.9s
# 11:	learn: 7041.6461978	total: 2.95s	remaining: 21.6s
# 12:	learn: 6871.6553295	total: 3.19s	remaining: 21.4s
# 13:	learn: 6708.7915668	total: 3.43s	remaining: 21.1s
# 14:	learn: 6552.8192237	total: 3.67s	remaining: 20.8s
# 15:	learn: 6402.5944795	total: 3.9s	remaining: 20.5s
# 16:	learn: 6259.2924178	total: 4.13s	remaining: 20.2s
# 17:	learn: 6121.3914221	total: 4.36s	remaining: 19.8s
# 18:	learn: 5988.6616776	total: 4.59s	remaining: 19.6s
# 19:	learn: 5862.1067602	total: 4.82s	remaining: 19.3s
# 20:	learn: 5739.5982685	total: 5.05s	remaining: 19s
# 21:	learn: 5623.5073252	total: 5.28s	remaining: 18.7s
# 22:	learn: 5510.9248383	total: 5.52s	remaining: 18.5s
# 23:	learn: 5403.2640632	total: 5.75s	remaining: 18.2s
# 24:	learn: 5301.0605868	total: 5.97s	remaining: 17.9s
# 25:	learn: 5201.5414384	total: 6.21s	remaining: 17.7s
# 26:	learn: 5108.5806577	total: 6.45s	remaining: 17.4s
# 27:	learn: 5016.6030840	total: 6.7s	remaining: 17.2s
# 28:	learn: 4929.5887097	total: 6.92s	remaining: 16.9s
# 29:	learn: 4847.1612673	total: 7.16s	remaining: 16.7s
# 30:	learn: 4765.5382809	total: 7.38s	remaining: 16.4s
# 31:	learn: 4686.5164253	total: 7.63s	remaining: 16.2s
# 32:	learn: 4611.6082641	total: 7.86s	remaining: 15.9s
# 33:	learn: 4540.8599941	total: 8.1s	remaining: 15.7s
# 34:	learn: 4473.5129961	total: 8.34s	remaining: 15.5s
# 35:	learn: 4408.7573299	total: 8.56s	remaining: 15.2s
# 36:	learn: 4345.8984759	total: 8.8s	remaining: 15s
# 37:	learn: 4285.5766508	total: 9.04s	remaining: 14.8s
# 38:	learn: 4226.8183446	total: 9.28s	remaining: 14.5s
# 39:	learn: 4169.9474630	total: 9.51s	remaining: 14.3s
# 40:	learn: 4116.0783682	total: 9.74s	remaining: 14s
# 41:	learn: 4064.0615921	total: 9.97s	remaining: 13.8s
# 42:	learn: 4014.4863508	total: 10.2s	remaining: 13.5s
# 43:	learn: 3966.4234546	total: 10.4s	remaining: 13.3s
# 44:	learn: 3918.2496695	total: 10.7s	remaining: 13s
# 45:	learn: 3872.2871659	total: 10.9s	remaining: 12.8s
# 46:	learn: 3829.0782908	total: 11.1s	remaining: 12.5s
# 47:	learn: 3789.0887340	total: 11.3s	remaining: 12.3s
# 48:	learn: 3749.8651178	total: 11.6s	remaining: 12s
# 49:	learn: 3712.1357125	total: 11.8s	remaining: 11.8s
# 50:	learn: 3675.8788176	total: 12s	remaining: 11.5s
# 51:	learn: 3641.2285888	total: 12.2s	remaining: 11.3s
# 52:	learn: 3607.7441686	total: 12.5s	remaining: 11.1s
# 53:	learn: 3575.3368715	total: 12.7s	remaining: 10.8s
# 54:	learn: 3544.3169607	total: 12.9s	remaining: 10.6s
# 55:	learn: 3514.2776686	total: 13.1s	remaining: 10.3s
# 56:	learn: 3485.5434855	total: 13.4s	remaining: 10.1s
# 57:	learn: 3457.7912073	total: 13.6s	remaining: 9.84s
# 58:	learn: 3429.1545810	total: 13.8s	remaining: 9.6s
# 59:	learn: 3403.6636547	total: 14.1s	remaining: 9.37s
# 60:	learn: 3377.4052293	total: 14.3s	remaining: 9.13s
# 61:	learn: 3353.6383983	total: 14.5s	remaining: 8.9s
# 62:	learn: 3330.4065651	total: 14.7s	remaining: 8.66s
# 63:	learn: 3309.0985055	total: 15s	remaining: 8.43s
# 64:	learn: 3287.4438031	total: 15.2s	remaining: 8.19s
# 65:	learn: 3267.0293629	total: 15.4s	remaining: 7.95s
# 66:	learn: 3246.0615914	total: 15.6s	remaining: 7.71s
# 67:	learn: 3227.0304551	total: 15.9s	remaining: 7.47s
# 68:	learn: 3208.6288702	total: 16.1s	remaining: 7.25s
# 69:	learn: 3190.3863701	total: 16.4s	remaining: 7.01s
# 70:	learn: 3174.0630048	total: 16.6s	remaining: 6.78s
# 71:	learn: 3157.9963178	total: 16.8s	remaining: 6.54s
# 72:	learn: 3142.6181126	total: 17.1s	remaining: 6.31s
# 73:	learn: 3127.6727031	total: 17.3s	remaining: 6.07s
# 74:	learn: 3112.4613989	total: 17.5s	remaining: 5.83s
# 75:	learn: 3098.7219164	total: 17.7s	remaining: 5.59s
# 76:	learn: 3084.5642732	total: 17.9s	remaining: 5.36s
# 77:	learn: 3071.3382627	total: 18.2s	remaining: 5.13s
# 78:	learn: 3058.5609870	total: 18.4s	remaining: 4.9s
# 79:	learn: 3044.4484589	total: 18.7s	remaining: 4.67s
# 80:	learn: 3032.9181620	total: 18.9s	remaining: 4.43s
# 81:	learn: 3021.7276996	total: 19.1s	remaining: 4.2s
# 82:	learn: 3010.1291352	total: 19.4s	remaining: 3.97s
# 83:	learn: 2998.9388828	total: 19.6s	remaining: 3.73s
# 84:	learn: 2988.7856308	total: 19.8s	remaining: 3.5s
# 85:	learn: 2976.6456993	total: 20.1s	remaining: 3.27s
# 86:	learn: 2966.9707482	total: 20.3s	remaining: 3.03s
# 87:	learn: 2957.4197832	total: 20.5s	remaining: 2.8s
# 88:	learn: 2948.3421708	total: 20.7s	remaining: 2.56s
# 89:	learn: 2939.6179367	total: 21s	remaining: 2.33s
# 90:	learn: 2931.6788291	total: 21.2s	remaining: 2.1s
# 91:	learn: 2923.9851690	total: 21.4s	remaining: 1.86s
# 92:	learn: 2914.6498321	total: 21.6s	remaining: 1.63s
# 93:	learn: 2907.7986548	total: 21.9s	remaining: 1.4s
# 94:	learn: 2901.1696912	total: 22.1s	remaining: 1.16s
# 95:	learn: 2894.2959055	total: 22.3s	remaining: 929ms
# 96:	learn: 2887.5804430	total: 22.5s	remaining: 697ms
# 97:	learn: 2881.3371005	total: 22.8s	remaining: 464ms
# 98:	learn: 2875.2901193	total: 23s	remaining: 232ms
# 2020-05-16 22:58:50,086 INFO:<ipython-input-15-c052d415860f> Training of lgbm_with_preproc
# 99:	learn: 2869.9723082	total: 23.2s	remaining: 0us
# /home/udimus/env/sber-task/lib/python3.6/site-packages/sklearn/model_selection/_split.py:667: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=5.
#   % (min_groups, self.n_splits)), UserWarning)
# /home/udimus/env/sber-task/lib/python3.6/site-packages/sklearn/model_selection/_split.py:667: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=5.
#   % (min_groups, self.n_splits)), UserWarning)
# /home/udimus/env/sber-task/lib/python3.6/site-packages/sklearn/model_selection/_split.py:667: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   % (min_groups, self.n_splits)), UserWarning)
# /home/udimus/env/sber-task/lib/python3.6/site-packages/sklearn/model_selection/_split.py:667: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   % (min_groups, self.n_splits)), UserWarning)
# /home/udimus/env/sber-task/lib/python3.6/site-packages/sklearn/model_selection/_split.py:667: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   % (min_groups, self.n_splits)), UserWarning)
# /home/udimus/env/sber-task/lib/python3.6/site-packages/sklearn/model_selection/_split.py:667: UserWarning: The least populated class in y has only 3 members, which is less than n_splits=5.
#   % (min_groups, self.n_splits)), UserWarning)
# /home/udimus/env/sber-task/lib/python3.6/site-packages/sklearn/model_selection/_split.py:667: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   % (min_groups, self.n_splits)), UserWarning)
# /home/udimus/env/sber-task/lib/python3.6/site-packages/sklearn/model_selection/_split.py:667: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=5.
#   % (min_groups, self.n_splits)), UserWarning)
# /home/udimus/env/sber-task/lib/python3.6/site-packages/sklearn/model_selection/_split.py:667: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   % (min_groups, self.n_splits)), UserWarning)
# /home/udimus/env/sber-task/lib/python3.6/site-packages/sklearn/model_selection/_split.py:667: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=5.
#   % (min_groups, self.n_splits)), UserWarning)
# /home/udimus/env/sber-task/lib/python3.6/site-packages/sklearn/model_selection/_split.py:667: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   % (min_groups, self.n_splits)), UserWarning)
# /home/udimus/env/sber-task/lib/python3.6/site-packages/sklearn/model_selection/_split.py:667: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   % (min_groups, self.n_splits)), UserWarning)
# /home/udimus/env/sber-task/lib/python3.6/site-packages/sklearn/model_selection/_split.py:667: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=5.
#   % (min_groups, self.n_splits)), UserWarning)
# /home/udimus/env/sber-task/lib/python3.6/site-packages/sklearn/model_selection/_split.py:667: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   % (min_groups, self.n_splits)), UserWarning)
# /home/udimus/env/sber-task/lib/python3.6/site-packages/sklearn/model_selection/_split.py:667: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   % (min_groups, self.n_splits)), UserWarning)
# /home/udimus/env/sber-task/lib/python3.6/site-packages/sklearn/model_selection/_split.py:667: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   % (min_groups, self.n_splits)), UserWarning)
# /home/udimus/env/sber-task/lib/python3.6/site-packages/sklearn/model_selection/_split.py:667: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   % (min_groups, self.n_splits)), UserWarning)
# /home/udimus/env/sber-task/lib/python3.6/site-packages/sklearn/model_selection/_split.py:667: UserWarning: The least populated class in y has only 3 members, which is less than n_splits=5.
#   % (min_groups, self.n_splits)), UserWarning)
# /home/udimus/env/sber-task/lib/python3.6/site-packages/sklearn/model_selection/_split.py:667: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   % (min_groups, self.n_splits)), UserWarning)
# /home/udimus/env/sber-task/lib/python3.6/site-packages/scipy/optimize/_minimize.py:511: RuntimeWarning: Method BFGS does not use Hessian information (hess).
#   RuntimeWarning)
# /home/udimus/env/sber-task/lib/python3.6/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is []
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# 2020-05-16 22:59:39,225 INFO:<ipython-input-15-c052d415860f> Training of lgbm
# /home/udimus/env/sber-task/lib/python3.6/site-packages/scipy/optimize/_minimize.py:511: RuntimeWarning: Method BFGS does not use Hessian information (hess).
#   RuntimeWarning)
# /home/udimus/env/sber-task/lib/python3.6/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is []
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))

# %%
test_data = pd.read_csv(os.path.join(DATA_PATH, TEST_FILE))

# %%
test_data.head()
# Out:
#    row_id feat_0 feat_1 feat_2 feat_3 feat_4   feat_5 feat_6 feat_7 feat_8  \
# 0       0      A      D      I      A      A  0.36083      A      B      A
# 1       1      A      E      E      A      A  0.52450      A      A      A
# 2       5      A      A      E      A      A  0.49462      A      A      A
# 3      13      A      D      A      A      A  0.82252      A      A      A
# 4      14      A      A      A      A      A  0.64027      A      A      A
#
#    ...  feat_120 feat_121 feat_122  feat_123 feat_124  feat_125 feat_126  \
# 0  ...         A        B        A        BI        B  0.298041        T
# 1  ...         B        H        A        BI        B  0.662480        R
# 2  ...         A        O        A        AB        A  0.677861        P
# 3  ...         A        L        A        BI        A  0.586522        T
# 4  ...         A        I        A        AB        A  0.284869        P
#
#   feat_127 feat_128 feat_129
# 0        A        A        B
# 1        A        A        B
# 2        A        A        D
# 3        A        A        B
# 4        A        A        B
#
# [5 rows x 131 columns]

# %%
PREDICTIONS_PATH = '../predictions/'

# %%
for name in final_pipelines:
    prediction_file = os.path.join(PREDICTIONS_PATH, f'{name}_test_prediction.csv')
    prediction_df = test_data[['row_id']].copy()
    prediction_df['prediction'] = final_pipelines[name].predict(X=test_data[test_data.columns[1:]])
    prediction_df.to_csv(prediction_file, index=False)

# %%
MODELS_PATH = '../models/'

# %%
name = 'cb_with_preproc'

save_pipeline(
    final_pipelines[name],
    os.path.join(MODELS_PATH, f'{name}_model.pkl.gz') 
)
# Out:
# 2020-05-16 23:02:59,540 INFO:model Pipeline saved as ../models/cb_with_preproc_model.pkl.gz

# %%
restored_pipeline = load_pipeline(os.path.join(MODELS_PATH, f'{name}_model.pkl.gz') )
# Out:
# 2020-05-16 23:03:18,255 INFO:model Pipeline loaded from ../models/cb_with_preproc_model.pkl.gz

# %%
restored_prediction = restored_pipeline.predict(X=test_data[test_data.columns[1:]])
original_prediction = final_pipelines[name].predict(X=test_data[test_data.columns[1:]])
assert (restored_prediction == original_prediction).all()

# %% [markdown]
# Итак, мы сохранили предсказания наших моделей -- а также одну модель, которая по кросс-валидации показалась самой эффективной.
